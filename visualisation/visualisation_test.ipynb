# %%
from visualisation import show_plot, water_mesh
import numpy as np
from scipy.spatial.transform import Rotation
import pyvista as pv
pv.set_jupyter_backend('client')

# %%
theta = 108 * 2*np.pi/360
r_oh = 0.5

# %%
n = 200
Lx, Ly, Lz = 20, 20, 20
R = Rotation.random(n)
quats = R.as_quat().reshape(4*n)
v = np.concatenate([
    -Lx/2 + Lx * np.random.rand(n),
    -Ly/2 + Ly * np.random.rand(n),
    -Lz/2 + Lz * np.random.rand(n),
    np.zeros(3 * n),
    quats
])

# %%
show_plot(n, v, Lx, Ly, Lz, theta, r_oh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 show_plot(n, v, Lx, Ly, Lz, theta, r_oh)
#
# File /mnt/shared/shared/phs3903/phs3903_projetfinal/visualisation/visualisation.py:57, in show_plot(n, v, Lx, Ly, Lz, theta, r_oh)
#      55 for i in range(n):
#      56     mol = water.copy(deep=False)
# ---> 57     mol.transform(T[i], inplace = True)
#      59     plotter.add_mesh(mol, scalars="rgb", rgb=True, line_width=5)
#      61 plotter.show()
#
# NameError: name 'T' is not defined
